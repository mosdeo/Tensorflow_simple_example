# %%
import tensorflow as tf
import matplotlib.image as mp_image
import matplotlib.pyplot as plt
import subprocess
import numpy as np
import cv2

# %%
# 預設 Session
sess = tf.Session()

# 讀取目錄底下所有檔案絕對路徑
paths_painful_image = subprocess.getoutput('find "PainImage/" -type f').split('\n')
print("count = {}".format(+len(paths_painful_image)))
# Out:
# count = 219

# %%
(x,y,w,h) = [116,57,118,118]

# %%
raw_img = cv2.imread(paths_painful_image[108])
# raw_img = cv2.imread('packt.jpeg', cv2.IMREAD_COLOR)
raw_img = cv2.cvtColor(raw_img, cv2.COLOR_BGR2RGB)               
print(type(raw_img))
print(raw_img.shape)
plt.imshow(raw_img)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# (240, 320, 3)

# %%
cv2.rectangle(mat,(x,y),(x+w,y+h),(255, 102, 0),1)
plt.imshow(mat[y:y+h, x:x+w])
plt.show()

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalcatface_extended.xml')
face_cascade.empty()
# Out:
# False

# %%
faces = ()
for i in range(len(paths_painful_image)):
    img = cv2.imread(paths_painful_image[i])
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    _faces = face_cascade.detectMultiScale(gray, 1.1, 3)
    if(() != _faces):
        print("{}, {}".format(i, _faces))
        faces = _faces
        for (x,y,w,h) in faces:
            img = img[y:y+h, x:x+w] # 只留 ROI
            print(img.shape)
            plt.imshow(cv2.resize(img, (int(img.shape[0]/3), int(img.shape[1]/3))))
            plt.show()
# Out:
# /home/lky/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: elementwise != comparison failed; this will raise an error in the future.
# 0, [[173 126  91  91]]
# (91, 91, 3)
# 2, [[178 126  78  78]]
# (78, 78, 3)
# 99, [[114  58 117 117]]
# (117, 117, 3)
# 101, [[123  61 108 108]]
# (108, 108, 3)
# 104, [[ 90  73 121 121]]
# (121, 121, 3)
# 106, [[ 90  66 124 124]]
# (124, 124, 3)
# 107, [[123  67 100 100]]
# (100, 100, 3)
# 108, [[120  60 113 113]]
# (113, 113, 3)
# 109, [[ 86  69 127 127]]
# (127, 127, 3)
# 114, [[ 82  65 137 137]]
# (137, 137, 3)
# 115, [[ 89  69 127 127]]
# (127, 127, 3)
# 118, [[ 90  71 122 122]]
# (122, 122, 3)
# 119, [[115  58 121 121]]
# (121, 121, 3)
# 121, [[117  58 113 113]]
# (113, 113, 3)
# 122, [[118  61 113 113]]
# (113, 113, 3)
# 125, [[120  62 111 111]]
# (111, 111, 3)

# %%
# for img_path in paths_painful_image[:10]:
#     ts_img = tf.image.decode_png(tf.read_file(img_path)) # tensorflow 讀取影像
#     plt.imshow(ts_img.eval(session=sess))
#     plt.show()
